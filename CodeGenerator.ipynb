# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/Colab Notebooks
# Out:
# /content/drive/My Drive/Colab Notebooks

# %%
# !git init
# !git config --global user.email "rarun1395@gmail.com"
# !git config --global user.name "arunkumar404"
# !git config --global init.defaultBranch main
# !git add CodeGenerator.ipynb
# !git commit -m "Initial commit"
# !git remote set-url origin https://github.com/arunkumar404/llmtocode.git
# !git push https://arunkumar404:<NEW_PAT>@github.com/arunkumar404/llmtocode.git
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/Colab Notebooks/.git/
# ^C
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-c7fef96edaf6> in <cell line: 7>()
#       5 get_ipython().system('git config credential.helper store')
#       6 get_ipython().system('git credential fill')
# ----> 7 username=arunkumar404
#       8 password=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
#       9 get_ipython().system('git add CodeGenerator.ipynb')
#
# NameError: name 'arunkumar404' is not defined
