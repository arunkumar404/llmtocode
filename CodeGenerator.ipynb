# %%
#Mount google drive for new session
from google.colab import drive
drive.mount('/content/drive')

#Install huggingface datasets or usage
# !pip install datasets

#Change to the Working Directory:
# %cd /content/drive/My Drive/Colab Notebooks

#Load the dataset
from datasets import load_dataset
dataset = load_dataset('iamtarun/python_code_instructions_18k_alpaca')

#Convert Dataset to DataFrame
import pandas as pd
df = pd.DataFrame(dataset['train'])
print(df)

# %%
# %cd /root/.ssh
# %ls -al

# Execute only if needed
# !ssh-keygen -t rsa -b 4096 -C "rarun1395@gmail.com"

# !cat /root/.ssh/id_rsa.pub
# !chmod 600 /root/.ssh/id_rsa

# %%
# Pushing changes to Git

# Configuration (Do once)
#!git init
# !git config --global user.email "rarun1395@gmail.com"
# !git config --global user.name "arunkumar404"
# !git config --global init.defaultBranch main

# # Set Remote URL (Do once)
# !git remote add origin git@github.com:arunkumar404/llmtocode.git

# %cd /content/drive/My Drive/Colab Notebooks
# !git config --global core.sshCommand "ssh -i /root/.ssh/id_rsa -o UserKnownHostsFile=/dev/null -o StrictHostKeyChecking=no"

# !git remote -v

# Execute only if needed
# !git remote remove origin
# !git remote add origin git@github.com:arunkumar404/llmtocode.git
# !git remote -v

# %cd /content/drive/My Drive/Colab Notebooks
# !git add .
# !git commit -m "All cells refactored"

# Execute only if needed
# !git push --set-upstream origin master

# !git push

# %%
# Data exploration

import pandas as pd

# Load dataset into a DataFrame
df = pd.read_json('your_dataset.json', orient='records', lines=True)
# Basic exploration
print(df.head())  # View first few entries
print(df.describe())  # Get descriptive statistics
# Out:
#                                          instruction  \
# 0  Create a function to calculate the sum of a se...
# 1  Generate a Python code for crawling a website ...
# 2  Create a Python list comprehension to get the ...
# 3   Generate a python script to perform this action.
# 4  Write a python script to generates random numb...
#
#                                                input  \
# 0                                    [1, 2, 3, 4, 5]
# 1  website: www.example.com \ndata to crawl: phon...
# 2
# 3  Given a string, remove all the consecutive dup...
# 4
#
#                                               output  \
# 0  # Python code\ndef sum_sequence(sequence):\n  ...
# 1  import requests\nimport re\n\ndef crawl_websit...
# 2                 [x*x for x in [1, 2, 3, 5, 8, 13]]
# 3  def remove_duplicates(string): \n    result = ...
# 4  def generate_random_divisible_number():\n    i...
#
#                                               prompt
# ...
