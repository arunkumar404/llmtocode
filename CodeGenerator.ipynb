# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/Colab Notebooks
# Out:
# /content/drive/My Drive/Colab Notebooks

# %%
# !git init
# !git config --global user.email "rarun1395@gmail.com"
# !git config --global user.name "arunkumar404"
# !git config --global init.defaultBranch main
# !git add CodeGenerator.ipynb
# !git commit -m "Initial commit"
# !git remote set-url origin git@github.com:arunkumar404/llmtocode.git
# !git push https://arunkumar404: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@github.com/arunkumar404/llmtocode.git
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/Colab Notebooks/.git/
# Generating public/private rsa key pair.
# Enter file in which to save the key (/root/.ssh/id_rsa): ^C
# [master b159baa] Initial commit
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite CodeGenerator.ipynb (67%)
# remote: Invalid username or password.
# fatal: Authentication failed for 'https://github.com/arunkumar404/llmtocode.git/'

# %%
# Out:
# Generating public/private rsa key pair.
# Enter file in which to save the key (/root/.ssh/id_rsa):
# Created directory '/root/.ssh'.
# Enter passphrase (empty for no passphrase):
# Enter same passphrase again:
# Your identification has been saved in /root/.ssh/id_rsa
# Your public key has been saved in /root/.ssh/id_rsa.pub
# The key fingerprint is:
# SHA256:23OeQC1uu3lTAQLhz595Gr6TARoMGYBfwnlheb0gClc rarun1395@gmail.com
# The key's randomart image is:
# +---[RSA 4096]----+
# |   o.+E=o+       |
# |  o =.B.o o .    |
# |   + = =.. o .   |
# |    o   ooo.  .  |
# |        So=..  . |
# |        .= o.o.  |
# |        . * *+.  |
# |         . O==   |
# |          +o*+   |
# +----[SHA256]-----+

# %%
# !cat /root/.ssh/id_rsa.pub
# Out:
# ssh-rsa ... rarun1395@gmail.com

# %%
# !eval $(ssh-agent -s)
# Out:
# Agent pid 14511

# %%
# !ssh-add /root/.ssh/id_rsa
# Out:
# Could not open a connection to your authentication agent.
