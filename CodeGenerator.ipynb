# %%
#Mount google drive for new session
from google.colab import drive
drive.mount('/content/drive')

#Install huggingface datasets or usage
# !pip install datasets

#Change to the Working Directory:
# %cd /content/drive/My Drive/Colab Notebooks

#Load the dataset
from datasets import load_dataset
dataset = load_dataset('iamtarun/python_code_instructions_18k_alpaca')

#Convert Dataset to DataFrame
import pandas as pd
df = pd.DataFrame(dataset['train'])
print(df)

# %%
# %cd /root
# %ls -al
# !ssh-keygen -t rsa -b 4096 -C "rarun1395@gmail.com"
# !cat /root/.ssh/id_rsa.pub
# Out:
# /root
# total 76
# drwx------ 1 root root 4096 Dec 21 06:44 ./
# drwxr-xr-x 1 root root 4096 Dec 21 05:57 ../
# -r-xr-xr-x 1 root root 1169 Jan  1  2000 .bashrc*
# drwxr-xr-x 1 root root 4096 Dec 21 05:58 .cache/
# drwx------ 1 root root 4096 Dec 21 06:16 .config/
# -rw-r--r-- 1 root root   86 Dec 21 06:44 .gitconfig
# drwxr-xr-x 1 root root 4096 Dec 19 14:37 .ipython/
# drwx------ 1 root root 4096 Dec 19 14:37 .jupyter/
# drwxr-xr-x 2 root root 4096 Dec 19 14:34 .keras/
# drwx------ 3 root root 4096 Dec 19 14:13 .launchpadlib/
# drwxr-xr-x 1 root root 4096 Dec 19 14:37 .local/
# drwxr-xr-x 4 root root 4096 Dec 19 14:37 .npm/
# -rw-r--r-- 1 root root  161 Jul  9  2019 .profile
# -r-xr-xr-x 1 root root  254 Jan  1  2000 .tmux.conf*
# -rw-r--r-- 1 root root  165 Dec 19 14:37 .wget-hsts
# Generating public/private rsa key pair.
# Enter file in which to save the key (/root/.ssh/id_rsa):
# Created directory '/root/.ssh'.
# Enter passphrase (empty for no passphrase):
# Enter same passphrase again:
# Your identification has been saved in /root/.ssh/id_rsa
# Your public key has been saved in /root/.ssh/id_rsa.pub
# The key fingerprint is:
# SHA256:zN1ZwVjN9fIrNKlQYR86eduouSqB/RllajTcG1YvC5I rarun1395@gmail.com
# The key's randomart image is:
# +---[RSA 4096]----+
# |           o =ooo|
# |          . *.o.+|
# |        . o=.o+ .|
# |       o E.Oo+=+ |
# |      o S.O **o..|
# |     . o +..=.. .|
# |        + o+ . . |
# |       . o  . .  |
# |        ....     |
# +----[SHA256]-----+
# ssh-rsa ... rarun1395@gmail.com

# %%
# !cat /root/.ssh/id_rsa.pub
# !chmod 600 /root/.ssh/id_rsa
# %cd /content/drive/My Drive/Colab Notebooks
# !git config --global core.sshCommand "ssh -i /root/.ssh/id_rsa -o UserKnownHostsFile=/dev/null -o StrictHostKeyChecking=no"

# !git remote -v
# %cd /content/drive/My Drive/Colab Notebooks
# !git add CodeGenerator.ipynb
# !git commit -m "All cells refactored"

# Push using PAT
# !git push
# Out:
# ssh-rsa ... rarun1395@gmail.com
# /content/drive/My Drive/Colab Notebooks
# origin	https://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@github.com/arunkumar404/llmtocode.git (fetch)
# origin	https://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@github.com/arunkumar404/llmtocode.git (push)
# /content/drive/My Drive/Colab Notebooks
# [master f9c7210] All cells refactored
#  1 file changed, 1 insertion(+), 1 deletion(-)
# fatal: could not read Password for 'https://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@github.com': No such device or address

# %%
#!git init
# !git remote add origin https://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github.com/arunkumar404/llmtocode.git
# !git push -u origin master


# Configuration (Do once)
# !git config --global user.email "rarun1395@gmail.com"
# !git config --global user.name "arunkumar404"
# !git config --global init.defaultBranch main

# # Set Remote URL (Do once)
# !git remote set-url origin https://github.com/arunkumar404/llmtocode.git

# To push changes
# %cd /content/drive/My Drive/Colab Notebooks
# !git add CodeGenerator.ipynb
# !git commit -m "All cells refactored"

# Push using PAT
# !git push
# Out:
# /content/drive/My Drive/Colab Notebooks
# [master 4901d14] All cells refactored
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite CodeGenerator.ipynb (89%)
# fatal: could not read Password for 'https://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@github.com': No such device or address

# %%
# first training sample
print(dataset['train'][0])
# first training sample features
print(dataset['train'].features)
