# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/Colab Notebooks

# %%
# !git init
# !git config --global user.email "rarun1395@gmail.com"
# !git config --global user.name "arunkumar404"
# !git add CodeGenerator.ipynb
# !git commit -m "Initial commit"
# !git remote add origin https://github.com/arunkumar404/llmtocode.git
# !git push -u origin master
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
