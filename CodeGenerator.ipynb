# %%
#Mount google drive for new session
from google.colab import drive
drive.mount('/content/drive')

#Install huggingface datasets or usage
# !pip install datasets

#Change to the Working Directory:
# %cd /content/drive/My Drive/Colab Notebooks

#Load the dataset
from datasets import load_dataset
dataset = load_dataset('iamtarun/python_code_instructions_18k_alpaca')

#Convert Dataset to DataFrame
import pandas as pd
df = pd.DataFrame(dataset['train'])
print(df)

# %%
#!git init
# !git remote add origin https://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github.com/arunkumar404/llmtocode.git
# !git push -u origin master



# Configuration (Do once)
# !git config --global user.email "rarun1395@gmail.com"
# !git config --global user.name "arunkumar404"
# !git config --global init.defaultBranch main

# # Set Remote URL (Do once)
# !git remote set-url origin https://github.com/arunkumar404/llmtocode.git

# To push changes
# !git add CodeGenerator.ipynb
# !git commit -m "All cells refactored"

# Push using PAT
import os
pat = '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'  # Replace with your actual PAT
os.system(f'git push https://{pat}@github.com/arunkumar404/llmtocode.git')
# Out:
# [master 1ed64e1] All cells refactored
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite CodeGenerator.ipynb (76%)
# 32768

# %%
# first training sample
print(dataset['train'][0])
# first training sample features
print(dataset['train'].features)
# Out:
# {'instruction': 'Create a function to calculate the sum of a sequence of integers.', 'input': '[1, 2, 3, 4, 5]', 'output': '# Python code\ndef sum_sequence(sequence):\n  sum = 0\n  for num in sequence:\n    sum += num\n  return sum', 'prompt': 'Below is an instruction that describes a task. Write a response that appropriately completes the request.\n\n### Instruction:\nCreate a function to calculate the sum of a sequence of integers.\n\n### Input:\n[1, 2, 3, 4, 5]\n\n### Output:\n# Python code\ndef sum_sequence(sequence):\n  sum = 0\n  for num in sequence:\n    sum += num\n  return sum'}
# {'instruction': Value(dtype='string', id=None), 'input': Value(dtype='string', id=None), 'output': Value(dtype='string', id=None), 'prompt': Value(dtype='string', id=None)}
